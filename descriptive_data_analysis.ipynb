# %% [markdown]
# <h1> Uygulamalı Veri Bilimi Ödevi Veri Analiz Bölümü </h1>

# %% [markdown]
# ## Pandas İmport ve Datayı Yükleme

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
original_data = pd.read_excel("data.xlsx")
data = original_data.copy()

# %% [markdown]
# ## Veri

# %%
data
# Out:
#     Bellek Hızı Cihaz Ağırlığı Ekran Boyutu Ekran Kartı Bellek Tipi  \
# 0      1066 MHz            NaN       10 inç                     NaN
# 1      1066 MHz            NaN       10 inç                     NaN
# 2      1066 MHz            NaN       10 inç                     NaN
# 3      3200 MHz       1 - 2 kg     15,6 inç                   GDDR4
# 4      3200 MHz       1 - 2 kg     15,6 inç                   GDDR5
# ..          ...            ...          ...                     ...
# 989    3200 MHz   2 kg ve Altı     15,6 inç                 Onboard
# 990    3200 MHz   2 kg ve Altı     15,6 inç                 Onboard
# 991    3200 MHz   2 kg ve Altı     15,6 inç                 Onboard
# 992    3200 MHz   2 kg ve Altı     15,6 inç                 Onboard
# 993    3200 MHz   2 kg ve Altı     15,6 inç                 Onboard
#
#     Ekran Kartı Hafızası    Ekran Kartı Tipi Ekran Panel Tipi İşlemci Nesli  \
# ...

# %% [markdown]
# data.xlsx dosyasındaki tüm veri seti yukarıdaki dataframe üzerinde görüntülenmektedir.

# %% [markdown]
# ### Veri Seti Hakkında Bilgiler

# %% [markdown]
# Bu kısımda Veri seti hakkında satır-sütun sayısı, kayıt sayıları, nitelik sayıları, nitelik tipleri gibi bilgiler aşağıda görüntülenmektedir.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Bellek Hızı              888 non-null    object
#  1   Cihaz Ağırlığı           985 non-null    object
#  2   Ekran Boyutu             994 non-null    object
#  3   Ekran Kartı Bellek Tipi  884 non-null    object
#  4   Ekran Kartı Hafızası     946 non-null    object
#  5   Ekran Kartı Tipi         955 non-null    object
#  6   Ekran Panel Tipi         994 non-null    object
#  7   İşlemci Nesli            946 non-null    object
#  8   İşlemci                  979 non-null    object
#  9   İşletim Sistemi          994 non-null    object
#  10  Kart Okuyucu             864 non-null    object
#  11  Aydınlatma               994 non-null    int64
#  12  Maksimum İşlemci Hızı    950 non-null    object
#  13  Max Ekran Çözünürlüğü    988 non-null    object
# ...

# %% [markdown]
# #### Tüm eleman sayısı

# %%
data.size
# Out:
# 18886

# %% [markdown]
# #### Satır Sütun Sayısı

# %%
data.shape
# Out:
# (994, 19)

# %% [markdown]
# #### Kayıt Sayısı

# %%
data.shape[0]
# Out:
# 994

# %% [markdown]
# #### Nitelik İsimleri

# %%
data.columns.to_list()
# Out:
# ['Bellek Hızı',
#  'Cihaz Ağırlığı',
#  'Ekran Boyutu',
#  'Ekran Kartı Bellek Tipi',
#  'Ekran Kartı Hafızası',
#  'Ekran Kartı Tipi',
#  'Ekran Panel Tipi',
#  'İşlemci Nesli',
#  'İşlemci',
#  'İşletim Sistemi',
#  'Kart Okuyucu',
#  'Aydınlatma',
#  'Maksimum İşlemci Hızı',
#  'Max Ekran Çözünürlüğü',
#  'Parmak İzi Okuyucu',
#  'Ram (Sistem Belleği)',
#  'SSD Kapasitesi',
#  'Ürün Modeli',
#  'Fiyat']

# %% [markdown]
# #### Nitelik Sayısı

# %%
data.shape[1]
# Out:
# 19

# %% [markdown]
# #### Nitelik Tipleri

# %%
data.dtypes
# Out:
# Bellek Hızı                object
# Cihaz Ağırlığı             object
# Ekran Boyutu               object
# Ekran Kartı Bellek Tipi    object
# Ekran Kartı Hafızası       object
# Ekran Kartı Tipi           object
# Ekran Panel Tipi           object
# İşlemci Nesli              object
# İşlemci                    object
# İşletim Sistemi            object
# Kart Okuyucu               object
# Aydınlatma                  int64
# Maksimum İşlemci Hızı      object
# Max Ekran Çözünürlüğü      object
# Parmak İzi Okuyucu         object
# Ram (Sistem Belleği)       object
# SSD Kapasitesi             object
# Ürün Modeli                object
# Fiyat                      object
# dtype: object

# %% [markdown]
# #### Nitelik İsimleri

# %%
data.columns.to_list()
# Out:
# ['Bellek Hızı',
#  'Cihaz Ağırlığı',
#  'Ekran Boyutu',
#  'Ekran Kartı Bellek Tipi',
#  'Ekran Kartı Hafızası',
#  'Ekran Kartı Tipi',
#  'Ekran Panel Tipi',
#  'İşlemci Nesli',
#  'İşlemci',
#  'İşletim Sistemi',
#  'Kart Okuyucu',
#  'Aydınlatma',
#  'Maksimum İşlemci Hızı',
#  'Max Ekran Çözünürlüğü',
#  'Parmak İzi Okuyucu',
#  'Ram (Sistem Belleği)',
#  'SSD Kapasitesi',
#  'Ürün Modeli',
#  'Fiyat']

# %% [markdown]
# #### Her Nitelik Altındaki Uniqe Değer Sayısı

# %%
data.nunique()
# Out:
# Bellek Hızı                16
# Cihaz Ağırlığı              4
# Ekran Boyutu               17
# Ekran Kartı Bellek Tipi     7
# Ekran Kartı Hafızası        8
# Ekran Kartı Tipi            3
# Ekran Panel Tipi           10
# İşlemci Nesli              22
# İşlemci                    87
# İşletim Sistemi             9
# Kart Okuyucu                2
# Aydınlatma                  2
# Maksimum İşlemci Hızı      37
# Max Ekran Çözünürlüğü      20
# Parmak İzi Okuyucu          2
# Ram (Sistem Belleği)       12
# SSD Kapasitesi             12
# Ürün Modeli                 4
# Fiyat                       5
# dtype: int64

# %% [markdown]
# #### Her Nitelik Altındaki Özellikler

# %%
data["Bellek Hızı"].unique()
# Out:
# array(['1066 MHz', '3200 MHz', '2933 MHz', nan, '2666 MHz', '2400 MHz',
#        '3000 MHz', '3733 MHz', '4267 MHz', '4800 MHz', '5200 MHz',
#        '4266 MHz', '6400 MHz', '1600 MHz', '5500 MHz', '1866 MHz',
#        '2133 MHz'], dtype=object)

# %%
data["Cihaz Ağırlığı"].unique()
# Out:
# array([nan, '1 - 2 kg', '2 - 4 kg', '2 kg ve Altı', '4 kg ve Üstü'],
#       dtype=object)

# %%
data["Ekran Boyutu"].unique()
# Out:
# array(['10 inç', '15,6 inç', '13,3 inç', '14 inç', '17,3 inç', '13 inç',
#        '16 inç', '16,1 inç', '12,3 inç', '14,1 inç', '18 inç', '18,4 inç',
#        '17 inç', '13,4 inç', '15 inç', '13,5 inç', '11,6 inç'],
#       dtype=object)

# %%
data["Ekran Kartı Bellek Tipi"].unique()
# Out:
# array([nan, 'GDDR4', 'GDDR5', 'GDDR6', 'Onboard', 'DDR3', 'DDR5',
#        'GDDR6X'], dtype=object)

# %%
data["Ekran Kartı Hafızası"].unique()
# Out:
# array(['1 GB', '2 GB', '4 GB', '8 GB', 'Paylaşımlı', '6 GB', nan, '12 GB',
#        '16 GB'], dtype=object)

# %%
data["Ekran Kartı Tipi"].unique()
# Out:
# array([nan, 'Harici Ekran Kartı', 'Yüksek Seviye Harici Ekran Kartı',
#        'Dahili Ekran Kartı'], dtype=object)

# %%
data["Ekran Panel Tipi"].unique()
# Out:
# array(['IPS', 'LED', 'TN', 'SVA', 'WVA', 'OLED', 'LTPS', 'Mini LED',
#        'Liquid Retina Ekran', 'Liquid Retina XDR'], dtype=object)

# %%
data["İşlemci Nesli"].unique()
# Out:
# array(['1.Nesil', '10. Nesil', '10.Nesil', 'Yok', '11.Nesil', '12.Nesil',
#        '13.Nesil', '3.Nesil', '4.Nesil', '5.Nesil', '6.Nesil', '7.Nesil',
#        '8.Nesil', '9.Nesil', 'Apple M2', 'Apple M2 Max', 'Apple M2 Pro',
#        'İntel N Serisi', 'M2', 'M2 Max', 'M2 Pro', 'Ryzen', nan],
#       dtype=object)

# %%
data["İşlemci"].unique()
# Out:
# array(['1000M', '1035G1', '10300H', '1135G7', 'N4020', '1065G7', '1005G1',
#        '10110U', '10. Nesil Intel® Core™ i3-10110U işlemci', '10200H',
#        '10750H', 'N5030', '10510U', '10210U', 'Celeron N4020', '1165G7',
#        '1155G7', '11320H', '11260H', '11370H', '11400H', '5600H',
#        '11800H', '11390H', '11600H', '1115G4', nan, '1195G7', '1125G4',
#        '12700H', '1255U', '1235U', '1260P', '12500H', '12450H', '12800H',
#        '12900HK', '12650H', '12900H', '1215U', '1240P', '13980HX',
#        '13900HX', '13500H', '6800H', '13700H', '13620H', '13650HX',
#        '13500HX', '13900H', '13700HX', '3700U', '3250U', 'AMD Ryzen 5',
#        'N4120', '5800H', 'T5600', '5500U', '5625U', '5825U', '5300U',
#        '5700U', '5675U', '6800HS', '6600H', '5257U', '1035G16', '7735HS',
#        '7940HS', '7320U', '7520U', '7530U', '7Y57', '7Y75', '8565U',
#        '9880H', '9300H', 'Apple M2', 'Apple M2 Max', 'Apple M2 Pro',
# ...

# %%
data["İşletim Sistemi"].unique()
# Out:
# array(['Android', 'Windows 10 Home', 'Yok (Free Dos)', 'Windows 11 Pro',
#        'Windows 11 Home', 'Windows 10 Pro', 'Ubuntu', 'macOS',
#        'Chrome OS'], dtype=object)

# %%
data["Kart Okuyucu"].unique()
# Out:
# array([nan, 'Var', 'Yok'], dtype=object)

# %%
data["Aydınlatma"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data["Maksimum İşlemci Hızı"].unique()
# Out:
# array(['1,05 GHz', '3,6 GHz', '4,5 GHz', '2,4 GHz', '2,8 GHz', '3,9 GHz',
#        '3,4 GHz', '4,1 GHz', '2,1 GHz', '4,2 GHz', '5 GHz', '3,1 GHz',
#        '4,9 GHz', '3,5 GHz', '1,1 GHz', '4,7 GHz', '4,4 GHz', '4,8 GHz',
#        '4,6 GHz', '2,3 GHz', '2,2 GHz', '3 GHz', '2,5 GHz', '1,2 GHz',
#        '3,7 GHz', '3,2 GHz', '4,3 GHz', '5,6 GHz', '5,4 GHz', '5,5 Ghz',
#        '4 GHz', '2,6 GHz', '4,0 GHz', '3,8 GHz', '5,2 GHz', nan, '2 GHz',
#        '1,8 GHz'], dtype=object)

# %%
data["Max Ekran Çözünürlüğü"].unique()
# Out:
# array([nan, '1920 x 1080', '1366 x 768', '1921 x 1080', '1920 x 1200',
#        '2560 x 1440', '1924 x 1080', '1933 x 1080', '1926 x 1080',
#        '1920 x 1280', '3840 x 2400', '3840 x 2160', '2560 x 1600',
#        '2520 x 1680', '2880 x 1800', '3072 x 1920', '1922 x 1080',
#        '2880 x 1864', '3456 x 2234', '3024 x 1964', '2880 x 1620'],
#       dtype=object)

# %%
data["Parmak İzi Okuyucu"].unique()
# Out:
# array([nan, 'Yok', 'Var'], dtype=object)

# %%
data["Ram (Sistem Belleği)"].unique()
# Out:
# array([nan, '8 GB', '12 GB', '16 GB', '32 GB', '4 GB', '20 GB', '24 GB',
#        '40 GB', '36 GB', '64 GB', '8\xa0GB', '128 GB'], dtype=object)

# %%
data["SSD Kapasitesi"].unique()
# Out:
# array(['1 TB', '512 GB', '256 GB', '128 GB', '120 GB', nan, '500 GB',
#        '4 TB', '0 GB', '250 GB', '2 TB', ' 0 GB', '64 GB'], dtype=object)

# %%
data["Ürün Modeli"].unique()
# Out:
# array(['Notebook', 'Oyun Bilgisayarları', 'İkisi Bir Arada', 'Ultrabook'],
#       dtype=object)

# %%
data["Fiyat"].unique()
# Out:
# array(['Çok Yüksek', 'Orta', 'Düşük', 'Çok Düşük', 'Yüksek'], dtype=object)

# %% [markdown]
# #### Düzeltilmesi Gereken Veriler

# %% [markdown]
# <ul>
# <li><b>İşlemci Nesli: </b>'10. Nesil Intel® Core™ i3-10110U işlemci' <b>-></b> '10110U' haline getirilmeli</li>
# <li><b>İşlemci: </b> '10. Nesil' <b>-></b>'10.Nesil' haline getirilmeli</li>
# <li><b>Ram (Sistem Belleği): </b>'8\xa0GB' <b>-></b> '8 GB' haline getirilmeli</li>
# <li><b>SSD Kapasitesi: </b>' 0 GB' <b>-></b> '0 GB' haline getirilmeli</li>
# </ul>

# %% [markdown]
# #### Her Sütundaki Toplam Boş Veri

# %%
data.isnull().sum()
# Out:
# Bellek Hızı                106
# Cihaz Ağırlığı               9
# Ekran Boyutu                 0
# Ekran Kartı Bellek Tipi    110
# Ekran Kartı Hafızası        48
# Ekran Kartı Tipi            39
# Ekran Panel Tipi             0
# İşlemci Nesli               48
# İşlemci                     15
# İşletim Sistemi              0
# Kart Okuyucu               130
# Aydınlatma                   0
# Maksimum İşlemci Hızı       44
# Max Ekran Çözünürlüğü        6
# Parmak İzi Okuyucu         108
# Ram (Sistem Belleği)         7
# SSD Kapasitesi               3
# Ürün Modeli                  0
# Fiyat                        0
# dtype: int64

# %% [markdown]
# #### Toplam Boş Veri

# %%
print("Toplam Boş Veri: ",data.isnull().sum().sum())
# Out:
# Toplam Boş Veri:  673

# %% [markdown]
# ## Merkezi Eğilim ve Merkezden Dağılım Ölçüleri

# %% [markdown]
# Merkezi Eğilim ve Merkezden Dağılım ölçülerinden Aralık(Range),Çeyreklikler (Quartiles), Inter-quartile range (IQR),Five Number Summary (min, Q1, median, Q3, max) , Aykırılıklar (Outliers) gibi tanımlayıcı veri analizleri yalnızca Aydınlatma Niteliği (Sütunu) üzerinde yapılabilir çünkü tek sayısal değere (int64) sahip nitelik bu niteliktir diğer nitelikler object tipinde olduğundan dolayı kalan nitelikler üzerinde sadece mod (en çok tekrar eden değer) bulma işlemi yapılmıştır.

# %% [markdown]
# #### Tüm Data Set için Mod Değerleri

# %%
mode_dataframe = data.mode()
mode_dataframe
# Out:
#   Bellek Hızı Cihaz Ağırlığı Ekran Boyutu Ekran Kartı Bellek Tipi  \
# 0    3200 MHz       1 - 2 kg     15,6 inç                 Onboard
#
#   Ekran Kartı Hafızası    Ekran Kartı Tipi Ekran Panel Tipi İşlemci Nesli  \
# 0           Paylaşımlı  Dahili Ekran Kartı              IPS      11.Nesil
#
#   İşlemci İşletim Sistemi Kart Okuyucu  Aydınlatma Maksimum İşlemci Hızı  \
# 0  1135G7  Yok (Free Dos)          Var           0               4,7 GHz
#
#   Max Ekran Çözünürlüğü Parmak İzi Okuyucu Ram (Sistem Belleği)  \
# 0           1920 x 1080                Yok                16 GB
#
#   SSD Kapasitesi Ürün Modeli  Fiyat
# 0         512 GB    Notebook  Düşük

# %% [markdown]
# ### Aydınlatma Niteliği için Detaylı Veri Analizi

# %%
data.describe()
# Out:
#        Aydınlatma
# count  994.000000
# mean     0.243461
# std      0.429387
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
data["Aydınlatma"].value_counts()
# Out:
# Aydınlatma
# 0    752
# 1    242
# Name: count, dtype: int64

# %%
sorted_data = data["Aydınlatma"].sort_values()
sorted_data
# Out:
# 0      0
# 621    0
# 622    0
# 623    0
# 624    0
#       ..
# 664    1
# 663    1
# 662    1
# 675    1
# 496    1
# Name: Aydınlatma, Length: 994, dtype: int64

# %% [markdown]
# #### Çeyreklikler (Quatilers) ve Çeyrekler Açıklığı (Inter-Quartile Range)

# %%
sorted_data = data["Aydınlatma"].sort_values()
q1 = sorted_data.quantile(0.25)
q3 = sorted_data.quantile(0.75)
iqr = q3 - q1

# %%
print("Q1: ",q1,"\nQ3: ",q3,"\nIQR: ",iqr)
# Out:
# Q1:  0.0
# Q3:  0.0
# IQR:  0.0

# %% [markdown]
# #### Aykırılıklar

# %%
alt_limit = q1 - (1.5 * iqr)
ust_limit = q3 + (1.5 * iqr)
print("Alt Limit: ",alt_limit,"\nÜst Limit: ", ust_limit)
# Out:
# Alt Limit:  0.0
# Üst Limit:  0.0

# %% [markdown]
# #### Five Number Summary

# %%
data.Aydınlatma.median()
# Out:
# 0.0

# %%
data.Aydınlatma.min()
# Out:
# 0

# %%
data.Aydınlatma.max()
# Out:
# 1

# %% [markdown]
#  Aydınlatma Niteliği için;
# <p> <b>Five Number Summary:</b>
# <ul>
#     <li><b>min:</b> 0</li>
#     <li><b>Q1:</b> 0.0</li>
#     <li><b>median:</b> 0.0</li>
#     <li><b>Q3:</b> 0.0</li>
#     <li><b>max:</b> 1</li>
# </ul>
# </p>

# %% [markdown]
# #### Aralık (Range)

# %%
range_value = data.Aydınlatma.max() - data.Aydınlatma.min()
print("Aralık (Range): ", range_value)
# Out:
# Aralık (Range):  1

# %% [markdown]
# ## Veri Görselleştirme Bölümü

# %% [markdown]
# ### Nitelik Değerlerinin Cihazlarda Bulunma Oranları

# %% [markdown]
# Bu kısımda her bir nitelik değerlerinden cihazların kaçında var veya cihazların üzerine dağılma oranları gösterilmiştir.

# %%
sns.countplot(y = data["Bellek Hızı"],color="#80B3FF")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("Bellek Hızı Oranları")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x = data["Ekran Boyutu"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("Ekran Boyutu Oranları")
plt.ylabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x = data["Ekran Kartı Bellek Tipi"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("Ekran Kartı Bellek Tipi Oranları")
plt.ylabel("Sayı")
plt.show()

# %%
sns.countplot(y = data["Ekran Kartı Hafızası"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("Ekran Kartı Hafızası")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x = data["Ekran Panel Tipi"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("Ekran Panel Tipi Oranları")
plt.ylabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(y = data["İşlemci Nesli"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("İşlemci Nesli Oranları")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(y = data["İşlemci"],color="#FF90BC")
fig = plt.gcf()
fig.set_size_inches(7,14)
plt.title("İşlemci Oranları")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(y = data["İşletim Sistemi"],color="#80B3FF")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("İşletim Sistemi Oranları")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(y = data["Maksimum İşlemci Hızı"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,8)
plt.title("Maksimum İşlemci Hızı Oranları")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(y = data["Max Ekran Çözünürlüğü"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,8)
plt.title("Max Ekran Çözünürlüğü Oranları")
plt.xlabel("Sayı")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x = data["Ram (Sistem Belleği)"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("Ram (Sistem Belleği) Oranları")
plt.ylabel("Sayı")
plt.xticks(rotation = 70)
plt.show()

# %%
sns.countplot(x = data["SSD Kapasitesi"],color="#FFA732")
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.title("SSD Kapasitesi Oranları")
plt.ylabel("Sayı")
plt.xticks(rotation = 70)
plt.show()

# %%
data["Cihaz Ağırlığı"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(5,5))
plt.title("Cihaz Ağırlıkların Oranları")
plt.ylabel("")
plt.show()

# %%
data["Ekran Kartı Tipi"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(5,5))
plt.title("Ekran Kartı Tipi Oranları")
plt.ylabel("")
plt.show()

# %%
data["Kart Okuyucu"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(5,5))
plt.title("Kart Okuyucu Oranları")
plt.ylabel("")
plt.show()

# %%
data["Aydınlatma"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(5,5))
plt.title("Aydınlatma Oranları")
plt.ylabel("")
plt.show()

# %%
data["Parmak İzi Okuyucu"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(5,5))
plt.title("Parmak İzi Okuyucu Oranları")
plt.ylabel("")
plt.show()

# %%
data["Ürün Modeli"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(7,7))
plt.title("Ürün Modeli Oranları")
plt.ylabel("")
plt.show()

# %%
data["Fiyat"].value_counts().plot.pie(autopct = "%1.1f%%",shadow=True,figsize =(5,5))
plt.title("Fiyat Oranları")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Farklı Niteliklerin veya Nitelik Kombinasyonlarının Fiyat Dağılımı

# %% [markdown]
# Bu kısımda çeşitli niteliklerin veya nitelik kombinasyonlarının fiyat üzerine etkisini/dağılımı gösterilmektedir.

# %% [markdown]
# #### Ekran Boyutu

# %%
sns.countplot(x="Ekran Boyutu", hue="Fiyat", data=data)
fig = plt.gcf()
fig.set_size_inches(13,8)
plt.title("Ekran Boyutu ve Fiyat")
plt.ylabel("Sayı")
plt.show()

# %% [markdown]
# #### İşlemci ve İşlemci Hızı

# %%
sns.stripplot(data=data, x="Maksimum İşlemci Hızı", y="İşlemci", hue="Fiyat")
fig = plt.gcf()
fig.set_size_inches(13,16)
plt.title("İşlemci/İşlemci Hızı ile Fiyat Bağıntısı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### İşlemci ve İşlemci Nesli

# %%
sns.stripplot(data=data, x="İşlemci Nesli", y="İşlemci", hue="Fiyat")
fig = plt.gcf()
fig.set_size_inches(14,16)
plt.title("İşlemci/İşlemci Hızı ile Fiyat Bağıntısı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### İşletim Sistemi

# %%
sns.displot(data, x="İşletim Sistemi" ,hue="Fiyat", multiple="stack")
fig = plt.gcf()
fig.set_size_inches(7,8)
plt.title("İşletim Sistemi ile Fiyat Bağıntısı")
plt.ylabel("Sayı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### SSD Kapasitesi ve RAM ile Fiyat Bağıntısı

# %%
sns.stripplot(data=data, x="Ram (Sistem Belleği)", y="SSD Kapasitesi", hue="Fiyat")
fig = plt.gcf()
fig.set_size_inches(13,8)
plt.title("SSD Kapasitesi ve RAM ile Fiyat Bağıntısı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Bellek Hızı

# %%
sns.displot(data, x="Fiyat", y="Bellek Hızı",color="#FF90BC")
fig = plt.gcf()
fig.set_size_inches(6,5)
plt.title("Bellek Hızı ile Fiyat Bağıntısı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Ekran Panel Tipi

# %%
sns.displot(data, x="Fiyat", y="Ekran Panel Tipi",color="#FFE5E5")
fig = plt.gcf()
fig.set_size_inches(6,5)
plt.title("Ekran Panel Tipi ile Fiyat Bağıntısı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Ekran Kartı Bellek Tipi ve Ekran Kartı Hafızası

# %%
sns.stripplot(data=data, x="Ekran Kartı Hafızası", y="Ekran Kartı Bellek Tipi", hue="Fiyat")
fig = plt.gcf()
fig.set_size_inches(9,7)
plt.title("Ekran Kartı Hafızası ve Ekran Kartı Bellek Tipi ile Fiyat Bağıntısı")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Parmak İzi Okuyucu

# %%
sns.countplot(data, x="Parmak İzi Okuyucu",hue="Fiyat")
fig = plt.gcf()
fig.set_size_inches(5,4)
plt.title("Ekran Panel Tipi ile Fiyat Bağıntısı")
plt.show()

# %%
sns.countplot(data, x="Ürün Modeli",hue="Fiyat")
fig = plt.gcf()
fig.set_size_inches(8,4)
plt.title("Ekran Panel Tipi ile Fiyat Bağıntısı")
plt.show()
